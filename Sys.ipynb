# %% [markdown]
# sys

# %% [markdown]
# The sys module in Python provides various functions and variables that are used to manipulate different parts of the Python runtime environment. It allows operating on the interpreter as it provides access to the variables and functions that interact strongly with the interpreter

# %% [markdown]
# sys.exc_info()

# %% [markdown]
# This function returns a tuple of three values that give information about the exception that is currently being handled. The information returned is specific both to the current thread and to the current stack frame. If the current stack frame is not handling an exception, the information is taken from the calling stack frame, or its caller, and so on until a stack frame is found that is handling an exception. Here, “handling an exception” is defined as “executing an except clause.” For any stack frame, only information about the exception being currently handled is accessible.

# %%
import sys

# %%
a = float(input("Enter a number"))
b = float(input("Enter a number"))

try:
  print(f"The answe is {a/b}")
except:
  print(sys.exc_info()[0])
  print("This did not work. Did you try to divide by zero or")
else:
  print("You succesfully used the division feature in Python")
finally:
  print("Thank you for playing")
# Out:
# Enter a number5
# Enter a number6
# The answe is 0.8333333333333334
# You succesfully used the division feature in Python
# Thank you for playing

# %% [markdown]
# sys.stdin

# %% [markdown]
# stdin is used for all interactive input (including calls to input());

# %%
import sys


for line in sys.stdin:
	if 'q' == line.rstrip():
		break
	print(f'Input : {line}')

print("Exit")
# Out:
# Exit

# %% [markdown]
# sys.exit()
#
# * sys.exit([arg]) can be used to exit the program. The optional argument arg can be an integer giving the exit or another type of object. If it is an integer, zero is considered “successful termination”.

# %%
# Python program to demonstrate
# sys.exit()


import sys


age = 17


if age < 18:
	
	# exits the program
	sys.exit("Age less than 18")	
else:
	print("Age is not less than 18")
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Age less than 18
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2890: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# sys.path
# * sys.path is a built-in variable within the sys module that
# returns the list of directories that the interpreter will search for the required module.

# %%
import sys

# Removing the values
sys.path = []

# importing pandas after removing
# values
import pandas
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-257fb17ca56a> in <module>()
#       6 # importing pandas after removing
#       7 # values
# ----> 8 import pandas
#
# ModuleNotFoundError: No module named 'pandas'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
